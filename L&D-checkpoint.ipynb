# %%
import pandas as pd
import os

# %%
df2=pd.read_csv("C:\\Users\\Wishes Lawrence\\Desktop\\lace-data1\\Desktop\\tenderdetails.csv")
df2
# Out:
#          TDR                               Tendering Authority  \
# 0   44279927                      Health And Medical Education
# 1   44269702                  Department of Defence Production
# 2   44263831                        Government Medical College
# 3   44246860                       Medical And Health Services
# 4   44244488                                       Indian Army
# 5   44236709             Employees State Insurance Corporation
# 6   44236696             Employees State Insurance Corporation
# 7   44230364                   Sawai Man Singh Medical College
# 8   44207555             Employees State Insurance Corporation
# 9   44205845                                       Indian Army
# 10  44201944   Department of Medical Health and Family Welfare
# 11  44190360   Maharashtra Medical Goods Procurement Authority
# 12  44190097             Employees State Insurance Corporation
# 13  44174020  West Bengal Medical Services Corporation Limited
# ...

# %%
df2['DueDate']
# Out:
# 0     08-08-2024
# 1     31-07-2024
# 2     06-08-2024
# 3     22-07-2024
# 4     18-07-2024
# 5     26-07-2024
# 6     26-07-2024
# 7     26-07-2024
# 8     15-07-2024
# 9     19-07-2024
# 10    22-07-2024
# 11    02-08-2024
# 12    23-07-2024
# 13    02-09-2024
# 14    24-07-2024
# 15    22-07-2024
# 16    01-08-2024
# 17    01-08-2024
# 18    24-07-2024
# 19    24-07-2024
# 20    24-07-2024
# 21    29-07-2024
# 22    11-07-2024
# 23    30-07-2024
# 24    23-07-2024
# 25    27-07-2024
# 26    29-07-2024
# 27    29-07-2024
# 28    27-07-2024
# 29    27-07-2024
# 30    27-07-2024
# 31    27-07-2024
# 32    25-07-2024
# 33    23-07-2024
# 34    22-07-2024
# 35    05-07-2024
# 36    05-07-2024
# 37    24-07-2024
# 38    15-07-2024
# 39    08-07-2024
# Name: DueDate, dtype: object

# %%
df2.columns
# Out:
# Index(['TDR', 'Tendering Authority', 'Tender Brief', 'DocumentFees', 'EMD',
#        'Tender Amount', 'Location', 'State', 'DueDate', 'TenderNo', 'Address',
#        'ContactEmail', 'TenderId'],
#       dtype='object')

# %%
graph=[]
for i in range(5):
    for j in range(5):
        print(graph[i][j],end="")
        print()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 4
#       2 for i in range(5):
#       3     for j in range(4):
# ----> 4         print(graph[i][j],end="")
#       5         print()
#
# IndexError: list index out of range
